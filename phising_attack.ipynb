# %% [markdown]
# <a href="https://colab.research.google.com/github/nihalbaig0/dphi_notebooks/blob/master/phising_attack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

phishing_data  = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/phishing_data/Training_set_label.csv" )

# %%
phishing_data.head()
# Out:
#                                                  url  ...      status
# 0     http://www.progarchives.com/album.asp?id=61737  ...    phishing
# 1  http://signin.eday.co.uk.ws.edayisapi.dllsign....  ...    phishing
# 2  http://www.avevaconstruction.com/blesstool/ima...  ...    phishing
# 3                              http://www.jp519.com/  ...  legitimate
# 4                       https://www.velocidrone.com/  ...  legitimate
#
# [5 rows x 89 columns]

# %%
phishing_data.describe()
# Out:
#          length_url  length_hostname  ...  google_index     page_rank
# count  11481.000000     11481.000000  ...  11481.000000  11481.000000
# mean      61.203902        21.129344  ...      0.535493      3.190837
# std       56.795786        10.633279  ...      0.498760      2.531696
# min       13.000000         4.000000  ...      0.000000      0.000000
# 25%       33.000000        15.000000  ...      0.000000      1.000000
# 50%       47.000000        19.000000  ...      1.000000      3.000000
# 75%       71.000000        24.000000  ...      1.000000      5.000000
# max     1641.000000       214.000000  ...      1.000000     10.000000
#
# [8 rows x 84 columns]

# %%
phishing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11481 entries, 0 to 11480
# Data columns (total 89 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   url                         11481 non-null  object
#  1   length_url                  11481 non-null  int64
#  2   length_hostname             11481 non-null  int64
#  3   ip                          11481 non-null  object
#  4   nb_dots                     11481 non-null  int64
#  5   nb_hyphens                  11481 non-null  object
#  6   nb_at                       11481 non-null  int64
#  7   nb_qm                       11481 non-null  int64
#  8   nb_and                      11481 non-null  int64
#  9   nb_or                       11481 non-null  int64
#  10  nb_eq                       11481 non-null  int64
#  11  nb_underscore               11481 non-null  int64
#  12  nb_tilde                    11481 non-null  int64
# ...

# %%
from sklearn.preprocessing import scale
df_region = pd.get_dummies(phishing_data,drop_first=True)

# %%
df_region.head()
# Out:
#    length_url  length_hostname  ...  domain_with_copyright_zero  status_phishing
# 0          46               20  ...                           0                1
# 1         128              120  ...                           1                1
# 2          52               25  ...                           1                1
# 3          21               13  ...                           0                0
# 4          28               19  ...                           1                0
#
# [5 rows x 8116 columns]

# %%
X = df_region.drop('status_phishing',axis=1)
y = df_region['status_phishing']
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    0
# Name: status_phishing, dtype: uint8

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
X_train ,  X_test,y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_scaled = scale(X_train)
print(X_train.shape)
print(y_train.shape)
# Out:
# (8036, 8115)
# (8036,)

# %%
ridge = Ridge(alpha=0.5,normalize=True)
ridge.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None, normalize=True,
#       random_state=None, solver='auto', tol=0.001)

# %%
y_pred = ridge.predict(X_test)

# %%
ridge.score(X_test,y_test)
# Out:
# 0.762781723686543

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = knn.predict(X_test)

# %%
knn.score(X_test,y_test)
# Out:
# 0.851335656213705

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
logreg.score(X_test,y_test)
# Out:
# 0.7860046457607434

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

param_grid = {'n_neighbors': np.arange(1, 50)}
knn = KNeighborsClassifier()
knn_cv = GridSearchCV(knn, param_grid, cv=5)
knn_cv.fit(X_train, y_train)
knn_cv.best_params_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-ca86c247dd47> in <module>()
#       6 knn = KNeighborsClassifier()
#       7 knn_cv = GridSearchCV(knn, param_grid, cv=5)
# ----> 8 knn_cv.fit(X_train, y_train)
#       9 knn_cv.best_params_
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# ...

# %%
# Import necessary modules
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

# Setup the parameters and distributions to sample from: param_dist
param_dist = {"max_depth": [3, None],
              "max_features": randint(1, 9),
              "min_samples_leaf": randint(1, 9),
              "criterion": ["gini", "entropy"]}

# Instantiate a Decision Tree classifier: tree
tree = DecisionTreeClassifier()
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

param_grid = {'n_neighbors': np.arange(1, 20)}
knn = KNeighborsClassifier()
# Instantiate the RandomizedSearchCV object: tree_cv
tree_cv = RandomizedSearchCV(knn, param_grid, cv=5)

# Fit it to the data
tree_cv.fit(X_train,y_train)

# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-8dcd74e399b8> in <module>()
#      21
#      22 # Fit it to the data
# ---> 23 tree_cv.fit(X_train,y_train)
#      24
#      25 # Print the tuned parameters and score
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1482         evaluate_candidates(ParameterSampler(
#    1483             self.param_distributions, self.n_iter,
# -> 1484             random_state=self.random_state))
#
# ...

# %%
tree_cv.score(X_test,y_test)
# Out:
# 0.8496371552975327

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls /content/gdrive/
# Out:
# 'My Drive'

# %%
model_save_name = 'classifier.pt'
path = F"/content/gdrive/My Drive/{model_save_name}" 
torch.save(model.state_dict(), path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-ac506fda1167> in <module>()
#       1 model_save_name = 'classifier.pt'
#       2 path = F"/content/gdrive/My Drive/{model_save_name}"
# ----> 3 torch.save(model.state_dict(), path)
#
# NameError: name 'torch' is not defined

# %%
test_data = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/phishing_data/Testing_set_label.csv')

# %%
test_data[1:].head()
# Out:
#                                                  url  ...  page_rank
# 1  http://www.sciencekids.co.nz/sciencefacts/anim...  ...          5
# 2  http://secureupdate.appleld.com.duilawyeryork....  ...          0
# 3  http://https.webmail.office.jezqmhyjbcaahq11ue...  ...          4
# 4                      https://blog.zen.co.uk/?p=356  ...          5
# 5                         https://www.menubus.audio/  ...          4
#
# [5 rows x 88 columns]

# %%
new_X = pd.get_dummies(test_data[1:],drop_first=True)

# %%
new_X.head()
# Out:
#    length_url  ...  domain_with_copyright_zero
# 1          60  ...                           0
# 2         118  ...                           0
# 3         261  ...                           0
# 4          29  ...                           1
# 5          26  ...                           1
#
# [5 rows x 3541 columns]

# %%
y_pred = tree_cv.predict(new_X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-9ec7340155a7> in <module>()
# ----> 1 y_pred = tree_cv.predict(new_X)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     114
#     115         # lambda, but not partial, allows help() to work with update_wrapper
# --> 116         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     117         # update the docstring of the returned function
#     118         update_wrapper(out, self.fn)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in predict(self, X)
#     475         """
#     476         self._check_is_fitted('predict')
# --> 477         return self.best_estimator_.predict(X)
#     478
#     479     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# ...
